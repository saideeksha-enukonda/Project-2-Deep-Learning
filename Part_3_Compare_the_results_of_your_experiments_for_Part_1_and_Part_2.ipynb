# %%
import matplotlib.pyplot as plt

# Test performance for each experiment
config_names = ['Configuration 1', 'Configuration 2', 'Configuration 3', 'Configuration 4', 'Configuration 5',
                'Configuration 6', 'Configuration 7', 'Configuration 8', 'Configuration 9', 'Configuration 10']

# Test accuracy for Fully Connected Classifier (FCC)
fcc_accuracy = [88.71, 88.52, 88.64, 88.39, 88.45, 88.38, 88.25, 88.49, 88.71, 88.48]

# Test accuracy for Convolutional Neural Network (CNN)
cnn_accuracy = [90.21, 90.27, 90.12, 90.09, 90.18, 90.07, 90.23, 90.14, 90.40, 90.19]

# Plotting test performance for each experiment
plt.figure(figsize=(10, 6))
plt.plot(config_names, fcc_accuracy, marker='o', label='FCC')
plt.plot(config_names, cnn_accuracy, marker='o', label='CNN')
plt.title('Test Performance of FCC vs CNN')
plt.xlabel('Configuration')
plt.ylabel('Test Accuracy')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting model complexity and training challenges
# Assuming we have training and validation accuracy data for both FCC and CNN configurations
# Replace 'fcc_train_acc', 'fcc_val_acc', 'cnn_train_acc', 'cnn_val_acc' with actual data

#  data for demonstration
fcc_train_acc = [0.88, 0.89, 0.87, 0.88, 0.86, 0.85, 0.84, 0.83, 0.82, 0.81]
fcc_val_acc = [0.82, 0.83, 0.81, 0.80, 0.79, 0.78, 0.77, 0.76, 0.75, 0.74]
cnn_train_acc = [0.90, 0.91, 0.89, 0.90, 0.88, 0.87, 0.86, 0.85, 0.84, 0.83]
cnn_val_acc = [0.84, 0.85, 0.83, 0.82, 0.81, 0.80, 0.79, 0.78, 0.77, 0.76]

# Plotting for FCC
plt.figure(figsize=(10, 6))
plt.plot(config_names, fcc_train_acc, marker='o', label='FCC Train Accuracy')
plt.plot(config_names, fcc_val_acc, marker='o', label='FCC Validation Accuracy')
plt.title('Model Complexity and Training Challenges - FCC')
plt.xlabel('Configuration')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting for CNN
plt.figure(figsize=(10, 6))
plt.plot(config_names, cnn_train_acc, marker='o', label='CNN Train Accuracy')
plt.plot(config_names, cnn_val_acc, marker='o', label='CNN Validation Accuracy')
plt.title('Model Complexity and Training Challenges - CNN')
plt.xlabel('Configuration')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
